# %%
import os
import cv2
import random
import numpy as np
from skimage import io, color, img_as_ubyte
from skimage.feature import greycomatrix, greycoprops
import os
from PIL import Image, ImageOps
import numpy as np
from keras_vggface.vggface import VGGFace
from sklearn.preprocessing import LabelBinarizer
import tensorflow as tf
from tensorflow.python.keras import layers
from tensorflow.python.keras import models
import random
from sklearn.model_selection import train_test_split
import pickle

model = VGGFace(model='resnet50')

# %%
class glcm:
    def __init__(self, image):
        distance = [1, 2, 3]
        angles = [0, np.pi/4, np.pi/2, 3*np.pi/4]
        self.image = img_as_ubyte(image.astype('int64'))
        self.glcm_mat = greycomatrix(self.image, distances = distance, angles = angles, symmetric = True, normed = True)
        self.properties = ['correlation', 'homogeneity', 'contrast', 'energy']
            
    def correlation(self):
        return greycoprops(self.glcm_mat, 'correlation').flatten()
    
    def homogeneity(self):
        return greycoprops(self.glcm_mat, 'homogeneity').flatten()
    
    def contrast(self):
        return greycoprops(self.glcm_mat, 'contrast').flatten()
    
    def energy(self):
        return greycoprops(self.glcm_mat, 'energy').flatten()
    
    def glcm_all(self):
        return np.hstack([greycoprops(self.glcm_mat, props).ravel() for props in self.properties])

# %%
def extract_glcm_feature(img):
    feats = glcm(img)
    # energy
    energy = feats.energy()
    # correlation
    corr = feats.correlation()
    # contrast
    cont = feats.contrast()
    # homogeneity
    homogeneity = feats.homogeneity()
    # all the features at once
    _all = feats.glcm_all()
    return {"energy":energy,
            "corr":corr, 
            "cont":cont, 
            "homogeneity":homogeneity, 
            "_all":_all}

# %%
from PIL import Image, ImageOps

Qry = Image.open('bg-4.jpg')
Qry = Qry.convert("RGB")
Qry = cv2.cvtColor(np.asarray(Qry), cv2.COLOR_RGB2BGR)
Qry = cv2.cvtColor(Qry, cv2.COLOR_BGR2GRAY)

print(extract_glcm_feature(Qry)['_all'])
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\skimage\util\dtype.py:525: UserWarning: Downcasting int64 to uint8 without scaling because max value 87 fits in uint8
#   return _convert(image, np.uint8, force_copy)
# [ 0.96079968  0.9787254   0.97024738  0.9134136   0.90049676  0.9787254
#   0.92006303  0.9134136   0.85896475  0.94695266  0.87519117  0.83035806
#   0.80638675  0.79633071  0.81262921  0.77740831  0.76290263  0.79633071
#   0.76389014  0.77740831  0.75714175  0.77333179  0.75199753  0.7528404
#   4.50783442  2.44463226  3.41902997  9.94952432 11.44172074  2.44463226
#   9.17909516  9.94952432 16.21652466  6.09067307 14.32102435 19.47765336
#   0.14650718  0.14226142  0.14792634  0.13946595  0.13601599  0.14226142
#   0.13595822  0.13946595  0.13545363  0.13789257  0.13394757  0.13449008]

# %%
x_classList = []
y_classList = []
base_path='images/'
source_path=base_path
for child in os.listdir(source_path):
#     print(child)
    X_list = 'x_list'+str(child)
    Y_list = 'y_list'+str(child)
    vars()[X_list] = []
    vars()[Y_list] = []
    x_classList.append(X_list)
    y_classList.append(Y_list)
    sub_path = os.path.join(source_path, child)
    bsub_path = os.path.join(base_path, child)
    if os.path.isdir(sub_path):
        for data_file in os.listdir(sub_path):
            Qry = Image.open(os.path.join(sub_path, data_file))
            Qry = Qry.convert("RGB")
            vars()[X_list].append(Qry)
            vars()[Y_list].append(child)
#     print(vars()[X_list])
#     print(vars()[Y_list])
print(x_classList)
print(y_classList)
# Out:
# ['x_lista', 'x_listananthan', 'x_listb']
# ['y_lista', 'y_listananthan', 'y_listb']

# %%
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelBinarizer

cnnCount = 0
ranCount = 0
for i in range(5):
    X = []
    for clas in x_classList:
        sample = random.sample(vars()[clas], 3)
        X.extend(sample)
#     print(X)

    Y = []
    for clas in y_classList:
        sample = random.sample(vars()[clas], 3)
        Y.extend(sample)
#     print(Y)
    labelBinarizer = LabelBinarizer()
    y = labelBinarizer.fit_transform(Y)
    
    X_glcm = []
    for img in X:
        img = cv2.cvtColor(np.asarray(img), cv2.COLOR_RGB2BGR)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        X_glcm.append(extract_glcm_feature(img)['_all'])
#     print(X_glcm)
    

    X_train, X_test, y_train, y_test = train_test_split(X_glcm, y, test_size=0.2, random_state=0)
    regressor = RandomForestRegressor(n_estimators=20, random_state=0)
    regressor.fit(X_train, y_train)
    y_pred = regressor.predict(X_test)
    print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
    print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))






    X_cnn = []
    for img in X:
        img = np.array(img.resize((224,224)))
        img = img.reshape([-1,224,224,3])
        features_train=model.predict([img])
        X_cnn.append(features_train.flatten())
#     print(X_cnn)

    X_train, X_test, y_train, y_test = train_test_split(X_cnn, y, test_size=0.2, random_state=0)
    print(X_test,y_test)
    random.seed(42)
    np.random.seed(42)
    #tf.random.set_seed(42)


    dnnModel=models.Sequential()
    dnnModel.add(layers.Dense(100,activation="tanh",input_shape=(8631,)))
    dnnModel.add(layers.Dense(50,activation="relu"))
    dnnModel.add(layers.Dense(30,activation="tanh"))
    dnnModel.add(layers.Dense(20,activation="relu"))
    dnnModel.add(layers.Dense(3,activation="softmax"))
    dnnModel.summary()



    dnnModel.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    tbCallBack=tf.keras.callbacks.TensorBoard(log_dir='.\Graph',histogram_freq=0,write_graph=True,write_images=True)

    dnnModel.fit(X_train,y_train,epochs=5,batch_size=4,callbacks=[tbCallBack])

    testloss, testAccuracy=dnnModel.evaluate(X_test,y_test)

    print(testAccuracy)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\skimage\util\dtype.py:525: UserWarning: Downcasting int64 to uint8 without scaling because max value 170 fits in uint8
#   return _convert(image, np.uint8, force_copy)
# C:\Users\user\Anaconda3\lib\site-packages\skimage\util\dtype.py:525: UserWarning: Downcasting int64 to uint8 without scaling because max value 163 fits in uint8
#   return _convert(image, np.uint8, force_copy)
# C:\Users\user\Anaconda3\lib\site-packages\skimage\util\dtype.py:525: UserWarning: Downcasting int64 to uint8 without scaling because max value 160 fits in uint8
#   return _convert(image, np.uint8, force_copy)
# C:\Users\user\Anaconda3\lib\site-packages\skimage\util\dtype.py:525: UserWarning: Downcasting int64 to uint8 without scaling because max value 181 fits in uint8
#   return _convert(image, np.uint8, force_copy)
# C:\Users\user\Anaconda3\lib\site-packages\skimage\util\dtype.py:525: UserWarning: Downcasting int64 to uint8 without scaling because max value 185 fits in uint8
#   return _convert(image, np.uint8, force_copy)
# C:\Users\user\Anaconda3\lib\site-packages\skimage\util\dtype.py:525: UserWarning: Downcasting int64 to uint8 without scaling because max value 184 fits in uint8
#   return _convert(image, np.uint8, force_copy)
# C:\Users\user\Anaconda3\lib\site-packages\skimage\util\dtype.py:525: UserWarning: Downcasting int64 to uint8 without scaling because max value 176 fits in uint8
#   return _convert(image, np.uint8, force_copy)
# C:\Users\user\Anaconda3\lib\site-packages\skimage\util\dtype.py:525: UserWarning: Downcasting int64 to uint8 without scaling because max value 173 fits in uint8
#   return _convert(image, np.uint8, force_copy)
# Mean Absolute Error: 0.3
# Mean Squared Error: 0.17333333333333334
# Root Mean Squared Error: 0.41633319989322654
# [array([3.6976717e-06, 8.6376508e-07, 2.7334111e-04, ..., 5.9596522e-07,
#        1.8479959e-06, 6.1097876e-06], dtype=float32), array([1.6850612e-05, 2.4985636e-07, 3.6601716e-05, ..., 7.0439746e-06,
#        9.2336768e-07, 7.1479308e-06], dtype=float32)] [[0 0 1]
#  [1 0 0]]
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               863200
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_2 (Dense)              (None, 30)                1530
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                620
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 63
# =================================================================
# Total params: 870,463
# Trainable params: 870,463
# Non-trainable params: 0
# _________________________________________________________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-1e9b4433e42a> in <module>
#      71     tbCallBack=tf.keras.callbacks.TensorBoard(log_dir='.\Graph',histogram_freq=0,write_graph=True,write_images=True)
#      72
# ---> 73     dnnModel.fit(X_train,y_train,epochs=5,batch_size=4,callbacks=[tbCallBack])
#      74
#      75     testloss, testAccuracy=dnnModel.evaluate(X_test,y_test)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     813           workers=workers,
#     814           use_multiprocessing=use_multiprocessing,
# --> 815           model=self)
#     816
#     817       # Container that configures and calls `tf.keras.Callback`s.
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model)
#    1110         use_multiprocessing=use_multiprocessing,
#    1111         distribution_strategy=ds_context.get_strategy(),
# -> 1112         model=model)
#    1113
#    1114     strategy = ds_context.get_strategy()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     280             label, ", ".join(str(i.shape[0]) for i in nest.flatten(data)))
#     281       msg += "Please provide data which shares the same first dimension."
# --> 282       raise ValueError(msg)
#     283     num_samples = num_samples.pop()
#     284
#
# ValueError: Data cardinality is ambiguous:
#   x sizes: 8631, 8631, 8631, 8631, 8631, 8631, 8631
#   y sizes: 7
# Please provide data which shares the same first dimension.
